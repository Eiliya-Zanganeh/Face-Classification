# %%
from train import train, test
# Out:
# Device: cuda | Device Name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
train()
# Out:
# Epoch [1/10]
# Train Loss:  1.9018 | Train Accuracy:  0.6966
# Validation Loss: 1.7143 | Validation Accuracy: 0.8229
# Epoch [2/10]
# Train Loss:  1.6313 | Train Accuracy:  0.7605
# Validation Loss: 1.4686 | Validation Accuracy: 0.8125
# Epoch [3/10]
# Train Loss:  1.4529 | Train Accuracy:  0.7863
# Validation Loss: 1.3144 | Validation Accuracy: 0.8542
# Epoch [4/10]
# Train Loss:  1.3179 | Train Accuracy:  0.7928
# Validation Loss: 1.3183 | Validation Accuracy: 0.7500
# Epoch [5/10]
# Train Loss:  1.1777 | Train Accuracy:  0.8232
# Validation Loss: 0.9825 | Validation Accuracy: 0.8333
# Epoch [6/10]
# Train Loss:  1.0979 | Train Accuracy:  0.8159
# Validation Loss: 0.9897 | Validation Accuracy: 0.8229
# Epoch [7/10]
# Train Loss:  1.0191 | Train Accuracy:  0.8296
# Validation Loss: 0.9974 | Validation Accuracy: 0.8125
# Epoch [8/10]
# Train Loss:  0.9285 | Train Accuracy:  0.8580
# Validation Loss: 0.7954 | Validation Accuracy: 0.8333
# Epoch [9/10]
# ...

# %%
test()
# Out:
# Test Loss: 0.9067, Test Accuracy: 84.38%
